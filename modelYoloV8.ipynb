# %%
# %pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO
import os
from IPython.display import Image, display
import pandas as pd
import matplotlib.pyplot as plt

# %%
model = YOLO('yolov8n.pt')

# %%
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
model.train(
    data=r'C:\Users\stanl\OneDrive\Documents\research\dataset\dataset.yaml',
    epochs=50,
    imgsz=640,
    batch=16,   
    name='jar_dent_detection_YOLOV8',
    pretrained=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.149 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.121  Python-3.12.4 torch-2.7.0+cpu CPU (AMD Ryzen 7 4700U with Radeon Graphics)
# ...

# %%
exp_name = 'jar_dent_detection_YOLOV8'
path = f'runs/detect/{exp_name}'

# %%
display(Image(filename=f'{path}/results.png'))
display(Image(filename=f'{path}/confusion_matrix.png'))
display(Image(filename=f'{path}/F1_curve.png'))
display(Image(filename=f'{path}/PR_curve.png'))

csv_path = f'{path}/results.csv'
df = pd.read_csv(csv_path)

plt.figure(figsize=(12, 6))
plt.plot(df['epoch'], df['metrics/precision(B)'], label='Precision')
plt.plot(df['epoch'], df['metrics/recall(B)'], label='Recall')
plt.plot(df['epoch'], df['metrics/mAP50(B)'], label='mAP@0.5')
plt.plot(df['epoch'], df['metrics/mAP50-95(B)'], label='mAP@0.5:0.95')
plt.plot(df['epoch'], df['train/box_loss'], label='Train Box Loss')
plt.plot(df['epoch'], df['train/cls_loss'], label='Train Class Loss')
plt.plot(df['epoch'], df['val/box_loss'], label='Val Box Loss', linestyle='--')

plt.xlabel('Epoch')
plt.ylabel('Value')
plt.title('Training Metrics Over Epochs')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
metrics = model.val()
print(metrics)
# Out:
# Ultralytics 8.3.121  Python-3.12.4 torch-2.7.0+cpu CPU (AMD Ryzen 7 4700U with Radeon Graphics)
# Model summary (fused): 72 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 801.2121.7 MB/s, size: 170.9 KB)
# val: Scanning C:\Users\stanl\OneDrive\Documents\research\dataset\labels\val.cache... 30 images, 0 backgrounds, 0 corrupt: 100%|██████████| 30/30 [00:00<?, ?it/s]
# c:\Users\stanl\anaconda3\Lib\site-packages\torch\utils\data\dataloader.py:665: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:04<00:00,  2.20s/it]
#                    all         30        340      0.908      0.897      0.978      0.933
#                damaged         30        159      0.963       0.81      0.978      0.943
# ...

# %%
results = model.predict(r'C:\Users\stanl\OneDrive\Documents\research\test\p214.JPG', save=True)
# Out:
# image 1/1 C:\Users\stanl\OneDrive\Documents\research\test\p214.JPG: 480x640 4 damageds, 9 intacts, 110.1ms
# Speed: 3.4ms preprocess, 110.1ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\jar_dent_detection_YOLOV83
